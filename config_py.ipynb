# %% [markdown]
# <a href="https://colab.research.google.com/github/harshalDharpure/Multimodality_Hateful_Meme/blob/main/config_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Modified for Hindi datasets Prompthate code

# %%
import argparse

def parse_opt():
    parser = argparse.ArgumentParser()

    # Dataset configuration
    parser.add_argument('--DATASET', type=str, default='mem',
                        help='Dataset name')

    # Few-shot learning settings
    parser.add_argument('--FEW_SHOT', type=bool, default=False,
                        help='Enable few-shot learning')
    parser.add_argument('--FINE_GRIND', type=bool, default=False,
                        help='Enable fine-grained labels')
    parser.add_argument('--NUM_SHOTS', type=int, default=16,
                        help='Number of shots for few-shot learning')

    # Model configuration
    parser.add_argument('--MODEL', type=str, default='pbm',
                        help='Model type (e.g., "pbm" or "roberta")')
    parser.add_argument('--UNIMODAL', type=bool, default=False,
                        help='Use a unimodal model (RoBERTa-based caption model)')

    # Paths to data and directories
    parser.add_argument('--DATA', type=str, default='../data',
                        help='Path to data directory')
    parser.add_argument('--CAPTION_PATH', type=str, default='../caption',
                        help='Path to caption directory')
    parser.add_argument('--RESULT', type=str, default='./result',
                        help='Path to save results')

    # Fixed model parameters
    parser.add_argument('--FEAT_DIM', type=int, default=2048,
                        help='Feature dimension')
    parser.add_argument('--CLIP_DIM', type=int, default=512,
                        help='Dimension of CLIP features')
    parser.add_argument('--BERT_DIM', type=int, default=768,
                        help='Dimension of BERT features')
    parser.add_argument('--ROBERTA_DIM', type=int, default=1024,
                        help='Dimension of RoBERTa features')
    parser.add_argument('--NUM_FOLD', type=int, default=5,
                        help='Number of cross-validation folds')
    parser.add_argument('--EMB_DIM', type=int, default=300,
                        help='Embedding dimension')
    parser.add_argument('--NUM_LABELS', type=int, default=2,
                        help='Number of labels')

    # Positive and negative words for fine-grained labels
    parser.add_argument('--POS_WORD', type=str, default='good',
                        help='Positive word for fine-grained labels')
    parser.add_argument('--NEG_WORD', type=str, default='bad',
                        help='Negative word for fine-grained labels')

    # Constraints for demonstrations
    parser.add_argument('--DEM_SAMP', type=bool, default=False,
                        help='Apply constraints to demonstrations')
    parser.add_argument('--SIM_RATE', type=float, default=0.5,
                        help='Sampling rate for similar demonstrations')
    parser.add_argument('--IMG_RATE', type=float, default=0.5,
                        help='Image similarity rate for constraints')
    parser.add_argument('--TEXT_RATE', type=float, default=0.5,
                        help='Text similarity rate for constraints')
    parser.add_argument('--CLIP_CLEAN', type=bool, default=False,
                        help='Use clean or uncleaned image features from CLIP')

    # Multi-query settings
    parser.add_argument('--MULTI_QUERY', type=bool, default=True,
                        help='Enable multi-query (ensemble) during evaluation')
    parser.add_argument('--NUM_QUERIES', type=int, default=4,
                        help='Number of queries in multi-query setting')

    # Hyperparameters
    parser.add_argument('--EMB_DROPOUT', type=float, default=0.0,
                        help='Embedding dropout rate')
    parser.add_argument('--FC_DROPOUT', type=float, default=0.4,
                        help='Fully connected layer dropout rate')
    parser.add_argument('--WEIGHT_DECAY', type=float, default=0.01,
                        help='Weight decay for optimizer')
    parser.add_argument('--LR_RATE', type=float, default=1.3e-5,
                        help='Learning rate')
    parser.add_argument('--EPS', type=float, default=1e-8,
                        help='Epsilon value for numerical stability')
    parser.add_argument('--BATCH_SIZE', type=int, default=16,
                        help='Batch size')
    parser.add_argument('--FIX_LAYERS', type=int, default=2,
                        help='Number of layers to fix during training')
    parser.add_argument('--MID_DIM', type=int, default=512,
                        help='Dimension of intermediate layers')
    parser.add_argument('--NUM_HIDDEN', type=int, default=512,
                        help='Number of hidden units')

    # Text processing and model architecture
    parser.add_argument('--LENGTH', type=int, default=64,
                        help='Maximum text length')
    parser.add_argument('--TOTAL_LENGTH', type=int, default=256,
                        help='Total text length')
    parser.add_argument('--PREFIX_LENGTH', type=int, default=10,
                        help='Prefix text length')
    parser.add_argument('--NUM_SAMPLE', type=int, default=1,
                        help='Number of samples')
    parser.add_argument('--NUM_LAYER', type=int, default=8,
                        help='Number of layers in the model')
    parser.add_argument('--MODEL_NAME', type=str, default='roberta-large',
                        help='Model name (e.g., "roberta-large")')
    parser.add_argument('--PRETRAIN_DATA', type=str, default='conceptual',
                        help='Pretrained data source')
    parser.add_argument('--IMG_VERSION', type=str, default='clean',
                        help='Image version (e.g., "clean" or "uncleaned")')
    parser.add_argument('--MAPPING_TYPE', type=str, default='transformer',
                        help='Type of mapping model')
    parser.add_argument('--ADD_ENT', type=bool, default=True,
                        help='Add entity information')
    parser.add_argument('--ADD_DEM', type=bool, default=True,
                        help='Add demonstration information')

    # Debugging and saving options
    parser.add_argument('--DEBUG', type=bool, default=False,
                        help='Enable debugging mode')
    parser.add_argument('--SAVE', type=bool, default=False,
                        help='Save model checkpoints')
    parser.add_argument('--SAVE_NUM', type=int, default=100,
                        help='Number associated with saved model checkpoints')
    parser.add_argument('--EPOCHS', type=int, default=10,
                        help='Number of training epochs')

    # Random seed and CUDA device
    parser.add_argument('--SEED', type=int, default=1111,
                        help='Random seed for reproducibility')
    parser.add_argument('--CUDA_DEVICE', type=int, default=15,
                        help='CUDA device for training')

    # Warm-up steps for learning rate scheduling
    parser.add_argument('--WARM_UP', type=int, default=2000,
                        help='Number of warm-up steps for learning rate scheduling')

    # MM models related parameters
    parser.add_argument('--TRANS_LAYER', type=int, default=1,
                        help='Number of transformer layers')
    parser.add_argument('--NUM_HEAD', type=int, default=8,
                        help='Number of attention heads')

    args = parser.parse_args()
    return args
